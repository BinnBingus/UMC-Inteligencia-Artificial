# %% [markdown]
# <a href="https://colab.research.google.com/github/BinnBingus/PythonExercicios/blob/main/Exercicios_OMG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício 1

# %%
print("Ola Mundo") # Imprime Olá Mundo uau
# Out:
# Ola Mundo
